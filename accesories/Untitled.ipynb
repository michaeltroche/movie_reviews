# %%
def circuit_3_basis_gates(theta, phi, xi):
    #define circuit parameters
    n_qubits = 2
    circuit = QuantumCircuit(n_qubits, n_qubits)

    #build the circuit for the decomposed target
    circuit.rx(xi[6], 0)
    circuit.ry(theta[6], 0)
    circuit.rx(phi[6] + xi[4], 0)

    circuit.rx(xi[7], 1)
    circuit.ry(theta[7], 1)
    circuit.rx(phi[7] + xi[5], 1)

    circuit.rxx(pi/2, 0, 1) #MS 3

    #circuit.rx(xi[4], 0) #commuted through MS 3
    circuit.ry(theta[4], 0)
    circuit.rx(phi[4] +xi[2], 0)

    #circuit.rx(xi[5], 1) #commuted through MS 3
    circuit.ry(theta[5], 1)
    circuit.rx(phi[5] + xi[3], 1)

    circuit.rxx(pi/2, 0, 1) #MS 2

    #circuit.rx(xi[2], 0) #commuted through MS 2
    circuit.ry(theta[2], 0)
    circuit.rx(phi[2] +xi[0], 0)

    #circuit.rx(xi[3], 1) #commuted through MS 2
    circuit.ry(theta[3], 1)
    circuit.rx(phi[3] +xi[1], 1)

    circuit.rxx(pi/2, 0, 1) #MS 1

    #circuit.rx(xi[0], 0) #commuted through MS 1
    circuit.ry(theta[0], 0)
    circuit.rx(phi[0], 0)

    #circuit.rx(xi[1], 1) #commuted through MS 1
    circuit.ry(theta[1], 1)
    circuit.rx(phi[1], 1)

    circuit.id(0)#shuttling time
    circuit.id(1)#shuttling time
    
    circuit.measure([0, 1], [0, 1])

    sigma = return_sigma(circuit)

    return sigma

def circuit_2_basis_gates(theta, phi, xi):
    #define circuit parameters
    n_qubits = 2
    circuit = QuantumCircuit(n_qubits, n_qubits)

    #build the circuit for the decomposed target

    circuit.rx(xi[4], 0) 
    circuit.ry(theta[4], 0)
    circuit.rx(phi[4] +xi[2], 0)

    circuit.rx(xi[5], 1)
    circuit.ry(theta[5], 1)
    circuit.rx(phi[5] + xi[3], 1)

    circuit.rxx(pi/2, 0, 1) #MS 2

    #circuit.rx(xi[2], 0) #commuted through MS 2
    circuit.ry(theta[2], 0)
    circuit.rx(phi[2] +xi[0], 0)

    #circuit.rx(xi[3], 1) #commuted through MS 2
    circuit.ry(theta[3], 1)
    circuit.rx(phi[3] +xi[1], 1)

    circuit.rxx(pi/2, 0, 1) #MS 1

    #circuit.rx(xi[0], 0) #commuted through MS 1
    circuit.ry(theta[0], 0)
    circuit.rx(phi[0], 0)

    #circuit.rx(xi[1], 1) #commuted through MS 1
    circuit.ry(theta[1], 1)
    circuit.rx(phi[1], 1)

    circuit.id(0) #shuttling time
    circuit.id(1) #shuttling time

    circuit.measure([0, 1], [0, 1])

    sigma = return_sigma(circuit)

    return sigma

def circuit_1_basis_gates(theta, phi, xi):
    #define circuit parameters
    n_qubits = 2
    circuit = QuantumCircuit(n_qubits, n_qubits)

    #build the circuit for the decomposed target

    circuit.rx(xi[2], 0)
    circuit.ry(theta[2], 0)
    circuit.rx(phi[2] +xi[0], 0)

    circuit.rx(xi[3], 1)
    circuit.ry(theta[3], 1)
    circuit.rx(phi[3] +xi[1], 1)

    circuit.rxx(pi/2, 0, 1) #MS 1

    #circuit.rx(xi[0], 0) #commuted through MS 1
    circuit.ry(theta[0], 0)
    circuit.rx(phi[0], 0)

    #circuit.rx(xi[1], 1) #commuted through MS 1
    circuit.ry(theta[1], 1)
    circuit.rx(phi[1], 1)

    circuit.id(0)#shuttling time
    circuit.id(1)#shuttling time

    circuit.measure([0, 1], [0, 1])

    sigma = return_sigma(circuit)

    return sigma

def circuit_0_basis_gates(theta, phi, xi):
    #define circuit parameters
    n_qubits = 2
    circuit = QuantumCircuit(n_qubits, n_qubits)

    #build the circuit for the decomposed target

    circuit.rx(xi[0], 0)
    circuit.ry(theta[0], 0)
    circuit.rx(phi[0], 0)

    circuit.rx(xi[1], 1)
    circuit.ry(theta[1], 1)
    circuit.rx(phi[1], 1)

    circuit.id(0)#shuttling time
    circuit.id(1)#shuttling time

    circuit.measure([0, 1], [0, 1])

    sigma = return_sigma(circuit)
    return sigma
