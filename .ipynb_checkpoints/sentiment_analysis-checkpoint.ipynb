# %% [markdown]
# # Movie Review Sentiment-Analysis

# %%
import pandas as pd
import os

print(os.listdir('./review_dfs'))
# Out:
# ['a_clockwork_orange.pkl', 'cannibal_holocaust.pkl', 'salò_o_le_120_giornate_di_sodoma_(salò,_or_the_120_days_of_sodom).pkl']

# %%
# Concatening dataframes
df = pd.DataFrame()

for df_file in os.listdir('./review_dfs'):    
    df_new = pd.read_pickle(f'./review_dfs/{df_file}')
    
    
    if df.empty:
        df = df_new
    else:
        df = pd.concat([df, df_new])

df.reset_index(inplace=True)
df
# Out:
# 33332
#        index       user  super_reviewer  profanity  \
# 0          0  979000867               0          0
# 1          1  979020486               0          1
# 2          2  962960458               0          0
# 3          3  976002415               0          0
# 4          4  978994452               0          0
# ...      ...        ...             ...        ...
# 33327   1556  116809431               0          0
# 33328   1557  900700775               0          0
# 33329   1558  900814229               0          0
# 33330   1559  900776865               0          0
# 33331   1560  900662277               0          0
#
#                                                   review  rating
# 0      A Clockwork Orange is without a doubt one of t...     4.0
# 1      This is a film. A film that wants you to sympa...     0.5
# 2      A Clockwork Orange is graphic, utterly bizarre...     3.0
# 3       Thought-provocative. Over-the-top nudity---yuck.     3.5
# 4      Sticks up to the plotline of the novel that is...     3.5
# ...                                                  ...     ...
# 33327                            Pasollini was a Genius!     5.0
# 33328  [img]http://images.rottentomatoes.com/images/u...     3.5
# 33329  Simply the most important movie about abuse of...     5.0
# 33330  [img]http://images.amazon.com/images/P/1559408...     1.5
# 33331  Ok, a follow up to the Carrot Top post. (Even ...     3.5
#
# [33332 rows x 6 columns]
